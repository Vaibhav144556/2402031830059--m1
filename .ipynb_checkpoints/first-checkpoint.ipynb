# %%
print("Hello Vaibhav")
# Out:
# Hello Vaibhav

# %%
import numpy as np

a = np.array([10, 20, 30, 40])

print(a)
# Out:
# [10 20 30 40]

# %%
import numpy as np 
vector=np.array([10,30,50,39])
print(vector)
# Out:
# [10 30 50 39]

# %%
print(vector.dtype)
# Out:
# int64
